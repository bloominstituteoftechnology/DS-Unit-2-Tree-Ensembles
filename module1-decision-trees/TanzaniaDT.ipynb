# %%
# First let's import
# Let's do our imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import pandas_profiling
import seaborn as sns; sns.set()
import category_encoders as ce
from statistics import mode
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
# %matplotlib inline

# %%
# Let's get our data
Location = "../data/tanzania/"

train = pd.merge(pd.read_csv(Location + 'train_features.csv'),
                 pd.read_csv(Location + 'train_labels.csv'))
test = pd.read_csv(Location + 'test_features.csv')
sample_submission = pd.read_csv(Location + 'sample_submission.csv')

# %%
# Now Let's do our test(val)-train split

train, val = train_test_split(train, train_size=0.80, test_size=0.20, random_state=42, 
                              stratify=train['status_group'])

train.shape, val.shape, test.shape
# Out:
# ((47520, 41), (11880, 41), (14358, 40))

# %%
train.sample(10)
# Out:
#           id  amount_tsh date_recorded                  funder  gps_height  \
# 6692   41501         0.0    2011-07-24                   Ridep           0
# 32683  45511         0.0    2011-07-05              Tanzakesho           0
# 27501  53086       500.0    2004-01-07                    Kkkt        1611
# 38576  16654         0.0    2012-10-15                     Dwe           0
# 51239  55809         0.0    2011-03-03                   Roman        2323
# 22710  32107       500.0    2013-03-24  Government Of Tanzania        1852
# 37108  27354         0.0    2011-03-13                      Rc        1942
# 52966  73077       100.0    2013-02-15                     Snv        1032
# 53017  42242         0.0    2011-03-28  Government Of Tanzania        1286
# 53275  37936         0.0    2013-03-26  Losaa-kia Water Supply        1289
#
#                        installer  longitude   latitude  \
# 6692                       RIDEP  32.951330  -2.719656
# 32683                        DWE  33.062487  -9.312613
# 27501                  Villagers  34.900561  -8.873813
# 38576                        DWE  33.092835  -4.025903
# 51239                      Commu  34.252534  -9.269225
# 22710                        DWE  36.647174  -3.253586
# 37108                         RC  34.499608  -9.247328
# 52966  UMOJA DRILLING CONTRACTOR  35.877711 -10.244966
# 53017                        DWE  38.355593  -4.901969
# 53275       Losaa-Kia water supp  37.111317  -3.188091
#
#                      wpt_name  num_private  ... water_quality quality_group  \
# 6692                 Kwa Buge            0  ...         milky         milky
# 32683                 Simbeye            0  ...          soft          good
# 27501  Kwa Barnabasi Kilumile            0  ...          soft          good
# 38576                   Ubada            0  ...       unknown       unknown
# 51239                    none            0  ...          soft          good
# 22710              Kwa Loitai            0  ...          soft          good
# 37108          Daudi Mbilinyi            0  ...          soft          good
# 52966               Kwa Mtupa            0  ...          soft          good
# 53017           Kwa Mzee Hope           65  ...          soft          good
# 53275      Kwa Aletaulo Munuo            0  ...          soft          good
#
#            quantity  quantity_group        source   source_type source_class  \
# 6692         enough          enough  shallow well  shallow well  groundwater
# 32683        enough          enough        spring        spring  groundwater
# 27501        enough          enough      hand dtw      borehole  groundwater
# 38576       unknown         unknown        spring        spring  groundwater
# 51239        enough          enough        spring        spring  groundwater
# 22710  insufficient    insufficient        spring        spring  groundwater
# 37108        enough          enough        spring        spring  groundwater
# 52966  insufficient    insufficient  shallow well  shallow well  groundwater
# 53017        enough          enough        spring        spring  groundwater
# 53275        enough          enough        spring        spring  groundwater
#
#           waterpoint_type waterpoint_type_group    status_group
# 6692                other                 other  non functional
# 32683               other                 other      functional
# 27501           hand pump             hand pump      functional
# 38576  communal standpipe    communal standpipe  non functional
# 51239  communal standpipe    communal standpipe      functional
# 22710  communal standpipe    communal standpipe      functional
# 37108  communal standpipe    communal standpipe      functional
# 52966           hand pump             hand pump      functional
# 53017  communal standpipe    communal standpipe      functional
# 53275  communal standpipe    communal standpipe      functional
#
# [10 rows x 41 columns]

# %%
# We're familiar with this data
# First let's engineer some of our features
def organize(X):
    """Function will organize the features of train, validate and test sets in the same way"""
    X = X.copy()
    
    # We'll start with latitude and it's tiny values
    # First, we have to replace these values with 0
    X['latitude'] = X['latitude'].replace(-2e-08, 0)
    
    # Now those values are the same as the incorrect null values in some of our other features
    colsw0s = ['longitude', 'latitude', 'population','construction_year'] #also construction year, but we'll get to that
    
    # We'll turn those 0's into np.nan the replace them with the mean of their columns
    for col in colsw0s:
        X[col] = X[col].replace(0, np.nan)
        X[col] = X[col].fillna(X[col].mean())
    
    # For construction_year we'll replace with the mode
#     X['construction_year'] = X['construction_year'].replace(0, np.nan)
#     XnoNan = X['construction_year'].dropna()
#     md = XnoNan.mode()
#     X['construction_year'] = X['construction_year'].fillna(md)
    
    # Next we'll convert date_recorded to datetime
    X['date_recorded'] = pd.to_datetime(X['date_recorded'], infer_datetime_format=True)
    
    # And we'll extract year_recorded also
    X['year_recorded'] = X['date_recorded'].dt.year
    
    # And we'll drop the column quantity_group as it is a duplicate of quantity
    X = X.drop(columns='quantity_group')
    
    # And we'll fill the missing values for categorical features with 'MISSING'
    cats = X.select_dtypes(exclude='number').columns
    for col in cats:
        X[col] = X[col].fillna('MISSING')
        
    return X

train = organize(train)
val = organize(val)
test = organize(test)

# %%
train.sample(20)
# Out:
#           id  amount_tsh date_recorded                  funder  gps_height  \
# 54389  50506       500.0    2013-08-02                  Danida         448
# 8044   61827      1000.0    2011-07-28                      Il        1688
# 56068  59173         0.0    2011-07-10                  Hesawa           0
# 4784   17163        50.0    2011-03-16      Private Individual          98
# 56659  24487        20.0    2011-03-17              World Bank         458
# 53884  35195         0.0    2013-03-12                       0         -15
# 54544  46762      1000.0    2013-03-27            World Vision         964
# 48451  72357        30.0    2013-01-11                 MISSING        1601
# 28695  42994         0.0    2013-01-18                Wateraid           0
# 9378   11457         0.0    2011-08-12                    Kkkt           0
# 12323  57159        50.0    2011-02-28      Private Individual         189
# 17392  49002        50.0    2011-03-30      Private Individual        1266
# 38545  41430         0.0    2011-03-25  Government Of Tanzania         267
# 41986  12057         0.0    2012-10-10                Oxfam Gb           0
# 11080  28070        30.0    2011-02-23                   Jaica          -9
# 30202  61720         0.0    2011-04-09                   Water           0
# 51167  32468       100.0    2013-01-19                   Norad        1116
# 10152  61997         0.0    2011-03-14                     Dhv         269
# 45121  42304         0.0    2013-03-02  Government Of Tanzania        1332
# 57621   5584       500.0    2011-03-12                  I Wash         377
#
#           installer  longitude   latitude                 wpt_name  \
# 54389        DANIDA  34.841433 -11.330271            Kwa Mzee Zuru
# 8044           CONS  31.243547  -7.858653              Kwa Mwalimu
# 56068           DWE  31.424816  -1.202875                  Kwasaid
# 4784             WU  38.426893  -6.645277              Sefu Mgambo
# 56659         World  37.829495  -6.774188         Kwa Rajabu Chedi
# 53884             0  39.350549  -6.839205  Kwa Mzee Peter Kabekege
# 54544  World Vision  37.875679  -4.290554              Kwa Grayson
# 48451       MISSING  34.878513  -4.670221            Amana Primary
# 28695          SEMA  32.782117  -4.381812               Mbutu Kati
# 9378           KKKT  32.995464  -8.929842                  Mpito A
# 12323            Wa  38.388658  -6.264756  Kwa Jaji Kipenka[Funta]
# 17392            AD  36.853301  -6.130153                Minchenja
# 38545           DWE  36.904521  -7.830691              Kwamamapita
# 41986         TWESA  33.489249  -3.568746                  Shuleni
# 11080         JAICA  39.367553  -7.068162            Kwa Mkalapema
# 30202         Commu  35.973330  -6.101123                 Zahanati
# 51167           RWE  29.720403  -4.680749               Kwa Tulula
# 10152           RWE  36.667680  -8.092095                   School
# 45121  Central govt  37.683421  -3.711358                Msikitini
# 57621      Local te  37.747983  -6.004303                Sekondari
#
#        num_private  ... water_quality quality_group      quantity  \
# 54389            0  ...          soft          good        enough
# 8044             0  ...          soft          good  insufficient
# 56068            0  ...         salty         salty  insufficient
# 4784             0  ...          soft          good        enough
# 56659            0  ...          soft          good        enough
# 53884            0  ...          soft          good           dry
# 54544            0  ...          soft          good        enough
# 48451            0  ...          soft          good  insufficient
# 28695            0  ...         salty         salty        enough
# 9378             0  ...          soft          good      seasonal
# 12323            0  ...          soft          good        enough
# 17392            0  ...          soft          good        enough
# 38545            0  ...          soft          good  insufficient
# 41986            0  ...          soft          good  insufficient
# 11080            0  ...          soft          good        enough
# 30202            0  ...         salty         salty           dry
# 51167            0  ...          soft          good        enough
# 10152            0  ...          soft          good  insufficient
# 45121            0  ...          soft          good  insufficient
# 57621            0  ...          soft          good        enough
#
#                      source           source_type source_class  \
# 54389                spring                spring  groundwater
# 8044                  river            river/lake      surface
# 56068          shallow well          shallow well  groundwater
# 4784                  river            river/lake      surface
# 56659                 river            river/lake      surface
# 53884           machine dbh              borehole  groundwater
# 54544                spring                spring  groundwater
# 48451           machine dbh              borehole  groundwater
# 28695           machine dbh              borehole  groundwater
# 9378           shallow well          shallow well  groundwater
# 12323                 river            river/lake      surface
# 17392          shallow well          shallow well  groundwater
# 38545                 river            river/lake      surface
# 41986  rainwater harvesting  rainwater harvesting      surface
# 11080           machine dbh              borehole  groundwater
# 30202           machine dbh              borehole  groundwater
# 51167                 river            river/lake      surface
# 10152          shallow well          shallow well  groundwater
# 45121                spring                spring  groundwater
# 57621          shallow well          shallow well  groundwater
#
#                    waterpoint_type  waterpoint_type_group  \
# 54389           communal standpipe     communal standpipe
# 8044            communal standpipe     communal standpipe
# 56068                    hand pump              hand pump
# 4784            communal standpipe     communal standpipe
# 56659           communal standpipe     communal standpipe
# 53884                        other                  other
# 54544           communal standpipe     communal standpipe
# 48451           communal standpipe     communal standpipe
# 28695                    hand pump              hand pump
# 9378                         other                  other
# 12323           communal standpipe     communal standpipe
# 17392                    hand pump              hand pump
# 38545           communal standpipe     communal standpipe
# 41986           communal standpipe     communal standpipe
# 11080           communal standpipe     communal standpipe
# 30202  communal standpipe multiple     communal standpipe
# 51167  communal standpipe multiple     communal standpipe
# 10152                        other                  other
# 45121           communal standpipe     communal standpipe
# 57621                    hand pump              hand pump
#
#                   status_group year_recorded
# 54389               functional          2013
# 8044                functional          2011
# 56068           non functional          2011
# 4784            non functional          2011
# 56659               functional          2011
# 53884           non functional          2013
# 54544               functional          2013
# 48451               functional          2013
# 28695               functional          2013
# 9378            non functional          2011
# 12323               functional          2011
# 17392               functional          2011
# 38545           non functional          2011
# 41986           non functional          2012
# 11080               functional          2011
# 30202           non functional          2011
# 51167  functional needs repair          2013
# 10152               functional          2011
# 45121  functional needs repair          2013
# 57621               functional          2011
#
# [20 rows x 41 columns]

# %%
# Now we can work with our features
# We'll set the target first
target = 'status_group'

# Now we'll set a df with all train features except for our target and the id column
trainfeat = train.drop(columns=[target, 'id'])

# We'll also separate the numeric features into one list...
numfeat = trainfeat.select_dtypes(include='number').columns.tolist()

# And we'll get the cardinality of the non-numeric features...
cardinality = trainfeat.select_dtypes(exclude='number').nunique()

# And then we'll get the list for categorical features with cardinality <= 50
catfeat = cardinality[cardinality <= 50].index.tolist()

# Finally we'll combine those lists
feats = numfeat + catfeat

# %%
# Now let's take a look at cardinality
cardinality.sort_values()
# Out:
# recorded_by                  1
# public_meeting               3
# source_class                 3
# permit                       3
# quantity                     5
# management_group             5
# quality_group                6
# waterpoint_type_group        6
# payment_type                 7
# payment                      7
# source_type                  7
# waterpoint_type              7
# extraction_type_class        7
# water_quality                8
# basin                        9
# source                      10
# management                  12
# scheme_management           13
# extraction_type_group       13
# extraction_type             18
# region                      21
# lga                        124
# date_recorded              349
# funder                    1717
# installer                 1930
# ward                      2082
# scheme_name               2564
# subvillage               17232
# wpt_name                 30661
# dtype: int64

# %%
# and also catfeat
catfeat
# Out:
# ['basin',
#  'region',
#  'public_meeting',
#  'recorded_by',
#  'scheme_management',
#  'permit',
#  'extraction_type',
#  'extraction_type_group',
#  'extraction_type_class',
#  'management',
#  'management_group',
#  'payment',
#  'payment_type',
#  'water_quality',
#  'quality_group',
#  'quantity',
#  'source',
#  'source_type',
#  'source_class',
#  'waterpoint_type',
#  'waterpoint_type_group']

# %%
# and finally feats
feats
# Out:
# ['amount_tsh',
#  'gps_height',
#  'longitude',
#  'latitude',
#  'num_private',
#  'region_code',
#  'district_code',
#  'population',
#  'construction_year',
#  'year_recorded',
#  'basin',
#  'region',
#  'public_meeting',
#  'recorded_by',
#  'scheme_management',
#  'permit',
#  'extraction_type',
#  'extraction_type_group',
#  'extraction_type_class',
#  'management',
#  'management_group',
#  'payment',
#  'payment_type',
#  'water_quality',
#  'quality_group',
#  'quantity',
#  'source',
#  'source_type',
#  'source_class',
#  'waterpoint_type',
#  'waterpoint_type_group']

# %%
len(feats)
# Out:
# 31

# %%
# Now, let's choose some features to use for our decision tree
features = ['source_type', 'latitude','longitude']

# %%
# Now we can encode, then scale our features
# First we arrange our data into X features matrix and y target vector
xtrain = train[features]
ytrain = train[target]
xval = val[features]
yval = val[target]
xtest = test[features]

# Reminder-Encoder: fit_transform on train, transform on val & test
encoder = ce.OneHotEncoder(use_cat_names=True)
xtrain_encoded = encoder.fit_transform(xtrain)
xval_encoded = encoder.transform(xval)
xtest_encoded = encoder.transform(xtest)

# Reminder-Scaler: fit_transform on train, transform on val & test
scaler = RobustScaler()
xtrain_scaled = scaler.fit_transform(xtrain_encoded)
xval_scaled = scaler.transform(xval_encoded)
xtest_scaled = scaler.transform(xtest_encoded)

# %%
# We'll use logistic regression to get a baseline
lr = LogisticRegression(solver='lbfgs', multi_class='auto', n_jobs=-1)
lr.fit(xtrain_scaled, ytrain)
print('Logistic Regression Model/Baseline')
print(f'Train Acc: {lr.score(xtrain_scaled, ytrain)}')
print(f'Val Acc: {lr.score(xval_scaled, yval)}')
# Out:
# Logistic Regression Model/Baseline
# Train Acc: 0.5451388888888888
# Val Acc: 0.5454545454545454

# %%
# Now let's try to use a decision tree Classifier
dt = DecisionTreeClassifier(random_state=42)
dt.fit(xtrain_scaled, ytrain)
print('Decision Tree Model')
print(f'Train Acc: {dt.score(xtrain_scaled, ytrain)}')
print(f'Val Acc: {dt.score(xval_scaled, yval)}')
# Out:
# Decision Tree Model
# Train Acc: 0.9856271043771043
# Val Acc: 0.6557239057239057

# %%
# Big improvement from our baseline, but with some obvious overfitting,
# Now let's try to use the same Decision tree Classifier, but with max_depth=10
maxdtdepth=10
dt = DecisionTreeClassifier(max_depth=maxdtdepth, random_state=42)
dt.fit(xtrain_scaled, ytrain)
print(f'Decision Tree Model: Max Depth = {maxdtdepth}')
print(f'Train Acc: {dt.score(xtrain_scaled, ytrain)}')
print(f'Val Acc: {dt.score(xval_scaled, yval)}')
# Out:
# Decision Tree Model: Max Depth = 10
# Train Acc: 0.6760101010101011
# Val Acc: 0.6407407407407407

# %%
# We'll keep our max_depth at 10 to avoid overfitting
# Let's pick some different features and try to get it all done in one workflow
features = ['source_type', 'waterpoint_type', 'extraction_type_group', 'quantity', 'population', 
            'construction_year', 'latitude','longitude']

xtrain = train[features]
ytrain = train[target]
xval = val[features]
yval = val[target]
xtest = test[features]

# Reminder-Encoder: fit_transform on train, transform on val & test
encoder = ce.OneHotEncoder(use_cat_names=True)
xtrain_encoded = encoder.fit_transform(xtrain)
xval_encoded = encoder.transform(xval)
xtest_encoded = encoder.transform(xtest)

# Reminder-Scaler: fit_transform on train, transform on val & test
scaler = RobustScaler()
xtrain_scaled = scaler.fit_transform(xtrain_encoded)
xval_scaled = scaler.transform(xval_encoded)
xtest_scaled = scaler.transform(xtest_encoded)

maxdtdepth=10

dt = DecisionTreeClassifier(max_depth=maxdtdepth, random_state=42)
dt.fit(xtrain_scaled, ytrain)
print(f'Decision Tree Model: Max Depth = {maxdtdepth}')
print(f'Train Acc: {dt.score(xtrain_scaled, ytrain)}')
print(f'Val Acc: {dt.score(xval_scaled, yval)}')
# Out:
# Decision Tree Model: Max Depth = 10
# Train Acc: 0.7529250841750842
# Val Acc: 0.744023569023569

# %%
# Ok, we have a pretty good validation score, so let's predict on xtest and submit
ypred = dt.predict(xtest_scaled)

submission = sample_submission.copy()
submission['status_group'] = ypred
submission.to_csv('dtsubmission-03.csv', index=False)
