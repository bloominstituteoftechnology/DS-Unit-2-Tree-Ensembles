# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np 
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score,accuracy_score
from sklearn.pipeline import Pipeline
import category_encoders as ce
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier

# %%
LOCAL = '../data/tanzania/'
WEB = 'https://raw.githubusercontent.com/LambdaSchool/DS-Unit-2-Linear-Models/master/data/tanzania/'

train_features = pd.read_csv(WEB + 'train_features.csv')
train_labels = pd.read_csv(WEB + 'train_labels.csv')
test_features = pd.read_csv(WEB + 'test_features.csv')
sample_submission = pd.read_csv(WEB + 'sample_submission.csv')

assert train_features.shape == (59400, 40)
assert train_labels.shape == (59400, 2)
assert test_features.shape == (14358, 40)
assert sample_submission.shape == (14358, 2)

# %%
train_features.columns
# Out:
# Index(['id', 'amount_tsh', 'date_recorded', 'funder', 'gps_height',
#        'installer', 'longitude', 'latitude', 'wpt_name', 'num_private',
#        'basin', 'subvillage', 'region', 'region_code', 'district_code', 'lga',
#        'ward', 'population', 'public_meeting', 'recorded_by',
#        'scheme_management', 'scheme_name', 'permit', 'construction_year',
#        'extraction_type', 'extraction_type_group', 'extraction_type_class',
#        'management', 'management_group', 'payment', 'payment_type',
#        'water_quality', 'quality_group', 'quantity', 'quantity_group',
#        'source', 'source_type', 'source_class', 'waterpoint_type',
#        'waterpoint_type_group'],
#       dtype='object')

# %%
train_features.drop(['id', 'amount_tsh','num_private','quantity_group','recorded_by'],axis =1)
# Out:
#       date_recorded                    funder  gps_height  \
# 0        2011-03-14                     Roman        1390
# 1        2013-03-06                   Grumeti        1399
# 2        2013-02-25              Lottery Club         686
# 3        2013-01-28                    Unicef         263
# 4        2011-07-13               Action In A           0
# 5        2011-03-13       Mkinga Distric Coun           0
# 6        2012-10-01                      Dwsp           0
# 7        2012-10-09                     Rwssp           0
# 8        2012-11-03                  Wateraid           0
# 9        2011-08-03               Isingiro Ho           0
# 10       2011-02-20                   Private          62
# 11       2013-02-18                    Danida        1062
# 12       2012-10-14              World Vision           0
# 13       2013-03-15   Lawatefuka Water Supply        1368
# 14       2012-10-20                     Biore           0
# 15       2011-08-04                     Rudep        1645
# 16       2011-07-04                    Unicef        1703
# 17       2011-09-04                    Unicef        1656
# 18       2011-07-22                    Hesawa        1162
# 19       2011-02-22                    Danida        1763
# 20       2011-02-27                       Twe        2216
# 21       2013-02-10                      Dwsp           0
# 22       2011-10-04                    Unicef        1510
# 23       2013-11-03                       Isf         672
# 24       2013-01-21  African Development Bank        1645
# 25       2013-02-25    Government Of Tanzania        1273
# 26       2013-01-16                    Sobodo         200
# 27       2011-07-11                    Hesawa           0
# 28       2013-03-05    Government Of Tanzania        1443
# 29       2013-03-16   Lawatefuka Water Supply        1256
# ...             ...                       ...         ...
# 59370    2013-01-29                       NaN        1154
# 59371    2012-10-09               Netherlands           0
# 59372    2012-10-31                       Tlc           0
# 59373    2013-01-30                     Rudep        1137
# 59374    2012-10-29                     Rwssp           0
# 59375    2011-08-03    Government Of Tanzania          54
# 59376    2013-02-03                       NaN        1581
# 59377    2012-10-23    Government Of Tanzania           0
# 59378    2011-03-21                        Rc        2101
# 59379    2011-07-13                        Do           0
# 59380    2011-03-14                     Roman        1439
# 59381    2011-03-16       Mkinga Distric Coun           0
# 59382    2013-08-03                 Ces(gmbh)        1383
# 59383    2013-01-19                World Bank          11
# 59384    2011-07-10                   Concern           0
# 59385    2012-11-03                     Jaica        1327
# 59386    2011-08-22                       Adb        1786
# 59387    2013-03-12                         0          25
# 59388    2013-01-29                     Kidep        1414
# 59389    2011-08-06                        Co         783
# 59390    2011-08-04                     Rudep        1715
# 59391    2013-08-03    Government Of Tanzania         540
# 59392    2011-04-15    Government Of Tanzania           0
# 59393    2012-10-27                   Private           0
# 59394    2011-03-09                World Bank         351
# 59395    2013-05-03           Germany Republi        1210
# 59396    2011-05-07               Cefa-njombe        1212
# 59397    2011-04-11                       NaN           0
# 59398    2011-03-08                     Malec           0
# 59399    2011-03-23                World Bank         191
#
#                   installer  longitude      latitude  \
# 0                     Roman  34.938093 -9.856322e+00
# 1                   GRUMETI  34.698766 -2.147466e+00
# 2              World vision  37.460664 -3.821329e+00
# 3                    UNICEF  38.486161 -1.115530e+01
# 4                   Artisan  31.130847 -1.825359e+00
# 5                       DWE  39.172796 -4.765587e+00
# 6                      DWSP  33.362410 -3.766365e+00
# 7                       DWE  32.620617 -4.226198e+00
# 8                 Water Aid  32.711100 -5.146712e+00
# 9                   Artisan  30.626991 -1.257051e+00
# 10                  Private  39.209518 -7.034139e+00
# 11                   DANIDA  35.770258 -1.057417e+01
# 12             World vision  33.798106 -3.290194e+00
# 13     Lawatefuka water sup  37.092574 -3.181783e+00
# 14                   WEDECO  34.364073 -3.629333e+00
# 15                      DWE  31.444121 -8.274962e+00
# 16                      DWE  34.642439 -9.106185e+00
# 17                      DWE  34.569266 -9.085515e+00
# 18                      DWE  32.920154 -1.947868e+00
# 19                    Danid  34.508967 -9.894412e+00
# 20                      TWE  34.473430 -9.594990e+00
# 21                      DWE   0.000000 -2.000000e-08
# 22                      DWE  34.586901 -8.980014e+00
# 23                      ISF  37.940029 -4.125595e+00
# 24                      DWE  29.747066 -4.495568e+00
# 25                      DWE  37.422751 -3.317536e+00
# 26              Kilolo Star  39.370777 -9.942532e+00
# 27                      DWE  31.104257 -1.735361e+00
# 28         District council  37.611126 -3.263526e+00
# 29     Lawatefuka water sup  37.061688 -3.191989e+00
# ...                     ...        ...           ...
# 59370                   NaN  30.058731 -4.902633e+00
# 59371                   DWE  33.586406 -3.040369e+00
# 59372                   TLC  32.058548 -5.052101e+00
# 59373                Distri  32.125024 -6.784358e+00
# 59374                   DWE   0.000000 -2.000000e-08
# 59375                   DWE  39.046942 -5.061494e+00
# 59376                   NaN  34.821039 -5.076258e+00
# 59377            Government  33.437012 -4.423594e+00
# 59378                  ACRA  34.620387 -9.358405e+00
# 59379                    DO  31.613284 -1.820226e+00
# 59380                 Roman  34.942101 -9.849198e+00
# 59381                   DWE  38.835001 -4.880204e+00
# 59382                   DWE  37.454759 -3.323599e+00
# 59383            World bank  39.626009 -1.005750e+01
# 59384               CONCERN  30.667805 -2.483710e+00
# 59385              JAICA CO  33.951681 -2.021854e+00
# 59386                   DWE  31.738789 -8.532013e+00
# 59387                     0  39.176480 -6.957098e+00
# 59388                   DWE  30.692400 -3.593827e+00
# 59389                   DWE  30.646486 -7.365418e+00
# 59390                   DWE  31.370848 -8.258160e+00
# 59391            Government  38.044070 -4.272218e+00
# 59392            Government  33.009440 -8.520888e+00
# 59393               Private  33.866852 -4.287410e+00
# 59394              ML appro  37.634053 -6.124830e+00
# 59395                   CES  37.169807 -3.253847e+00
# 59396                  Cefa  35.249991 -9.070629e+00
# 59397                   NaN  34.017087 -8.750434e+00
# 59398                  Musa  35.861315 -6.378573e+00
# 59399                 World  38.104048 -6.747464e+00
#
#                         wpt_name                    basin          subvillage  \
# 0                           none               Lake Nyasa            Mnyusi B
# 1                       Zahanati            Lake Victoria             Nyamara
# 2                    Kwa Mahundi                  Pangani             Majengo
# 3           Zahanati Ya Nanyumbu  Ruvuma / Southern Coast          Mahakamani
# 4                        Shuleni            Lake Victoria          Kyanyamisa
# 5                         Tajiri                  Pangani         Moa/Mwereme
# 6                     Kwa Ngomho                 Internal       Ishinabulandi
# 7                   Tushirikiane          Lake Tanganyika     Nyawishi Center
# 8              Kwa Ramadhan Musa          Lake Tanganyika          Imalauduki
# 9                        Kwapeto            Lake Victoria            Mkonomre
# 10                 Mzee Hokororo              Wami / Ruvu              Mizugo
# 11              Kwa Alid Nchimbi               Lake Nyasa        Ngondombwito
# 12                         Pamba                 Internal             Nkilifa
# 13          Kwa John Izack Mmari                  Pangani             Omarini
# 14                     Mwabasabi                 Internal           Mwabasabi
# 15        Kwa Juvenal Ching'Ombe          Lake Tanganyika               Tunzi
# 16               Kwa John Mtenzi                   Rufiji            Kidudumo
# 17               Kwa Rose Chaula                   Rufiji              Yeriko
# 18                        Ngomee            Lake Victoria              Center
# 19                          none               Lake Nyasa            Manyanya
# 20                          none               Lake Nyasa             Majengo
# 21                      Muungano            Lake Victoria          Ibabachegu
# 22                       Shuleni                   Rufiji           Mkanivega
# 23                       Kinonga                  Pangani          Mkonga Juu
# 24                       Kamsasa          Lake Tanganyika               Msasa
# 25                     Kwa Tukai                  Pangani            Kitereni
# 26         Ruhoma Primary School  Ruvuma / Southern Coast             Shuleni
# 27                    Kwawilliam            Lake Victoria           Chakahaya
# 28                  Kwa Kibakaya                  Pangani               Kiyao
# 29             Kwa Willium Kinda                  Pangani              Merali
# ...                          ...                      ...                 ...
# 59370             Village Office          Lake Tanganyika            Mazungwe
# 59371                   Ushirika            Lake Victoria             Chambwa
# 59372           Kwa Mzee Kamanya          Lake Tanganyika    Urambo Magharibi
# 59373                Kwa Kadiega               Lake Rukwa           Mapambano
# 59374                 Nguvu Kazi            Lake Victoria          Mwamtani A
# 59375                  Sekondari                  Pangani          Kwa Nyanji
# 59376                    Nasingo                 Internal                  Hu
# 59377                       Fpct                 Internal            Hospital
# 59378             Michael Msigwa                   Rufiji            Igelango
# 59379            Coffee Plantati            Lake Victoria           Kaluyango
# 59380                       none               Lake Nyasa            Mnyusi B
# 59381                 Mijohoroni                  Pangani           Mtakuja A
# 59382             Kwa Luka Msaki                  Pangani            Yamu Juu
# 59383                    Shuleni  Ruvuma / Southern Coast           Mitumbati
# 59384                   Chamkube            Lake Victoria          Songambele
# 59385                Kwa Marunda            Lake Victoria             Mlimani
# 59386  Shule Ya Sekondari Katazi               Lake Rukwa               Nduza
# 59387                 Kwa Maliba              Wami / Ruvu  Mtaa Wa Yangeyange
# 59388         Kwa Philipo Kibeba          Lake Tanganyika            Kumwambu
# 59389                  Sekondari          Lake Tanganyika             Itete B
# 59390            Kwa Mzee Atanas          Lake Tanganyika             Kitonto
# 59391                        Kwa                  Pangani          Maore Kati
# 59392             Benard Charles               Lake Rukwa           Mbuyuni A
# 59393                  Kwa Peter                 Internal             Masanga
# 59394                 Chimeredya              Wami / Ruvu            Komstari
# 59395        Area Three Namba 27                  Pangani            Kiduruni
# 59396          Kwa Yahona Kuvala                   Rufiji            Igumbilo
# 59397                    Mashine                   Rufiji           Madungulu
# 59398                     Mshoro                   Rufiji              Mwinyi
# 59399            Kwa Mzee Lugawa              Wami / Ruvu        Kikatanyemba
#
#               region  ...                payment  payment_type water_quality  \
# 0             Iringa  ...           pay annually      annually          soft
# 1               Mara  ...              never pay     never pay          soft
# 2            Manyara  ...         pay per bucket    per bucket          soft
# 3             Mtwara  ...              never pay     never pay          soft
# 4             Kagera  ...              never pay     never pay          soft
# 5              Tanga  ...         pay per bucket    per bucket         salty
# 6          Shinyanga  ...              never pay     never pay          soft
# 7          Shinyanga  ...                unknown       unknown         milky
# 8             Tabora  ...              never pay     never pay         salty
# 9             Kagera  ...              never pay     never pay          soft
# 10             Pwani  ...              never pay     never pay         salty
# 11            Ruvuma  ...  pay when scheme fails    on failure          soft
# 12         Shinyanga  ...                  other         other          soft
# 13       Kilimanjaro  ...            pay monthly       monthly          soft
# 14         Shinyanga  ...              never pay     never pay          soft
# 15             Rukwa  ...              never pay     never pay          soft
# 16            Iringa  ...            pay monthly       monthly          soft
# 17            Iringa  ...  pay when scheme fails    on failure          soft
# 18            Mwanza  ...              never pay     never pay         milky
# 19            Iringa  ...           pay annually      annually          soft
# 20            Iringa  ...            pay monthly       monthly          soft
# 21         Shinyanga  ...                unknown       unknown       unknown
# 22            Iringa  ...              never pay     never pay          soft
# 23       Kilimanjaro  ...            pay monthly       monthly          soft
# 24            Kigoma  ...                unknown       unknown          soft
# 25       Kilimanjaro  ...                unknown       unknown          soft
# 26             Lindi  ...            pay monthly       monthly          soft
# 27            Kagera  ...              never pay     never pay          soft
# 28       Kilimanjaro  ...            pay monthly       monthly          soft
# 29       Kilimanjaro  ...            pay monthly       monthly          soft
# ...              ...  ...                    ...           ...           ...
# 59370         Kigoma  ...            pay monthly       monthly       unknown
# 59371      Shinyanga  ...              never pay     never pay          soft
# 59372         Tabora  ...         pay per bucket    per bucket         salty
# 59373          Rukwa  ...           pay annually      annually          soft
# 59374      Shinyanga  ...                  other         other          soft
# 59375          Tanga  ...            pay monthly       monthly          soft
# 59376        Singida  ...                unknown       unknown       unknown
# 59377         Tabora  ...              never pay     never pay          soft
# 59378         Iringa  ...            pay monthly       monthly          soft
# 59379         Kagera  ...              never pay     never pay          soft
# 59380         Iringa  ...           pay annually      annually          soft
# 59381          Tanga  ...              never pay     never pay          soft
# 59382    Kilimanjaro  ...         pay per bucket    per bucket          soft
# 59383          Lindi  ...                unknown       unknown          soft
# 59384         Kagera  ...              never pay     never pay          soft
# 59385           Mara  ...            pay monthly       monthly         salty
# 59386          Rukwa  ...              never pay     never pay          soft
# 59387  Dar es Salaam  ...         pay per bucket    per bucket          soft
# 59388         Kigoma  ...                unknown       unknown          soft
# 59389          Rukwa  ...              never pay     never pay          soft
# 59390          Rukwa  ...              never pay     never pay          soft
# 59391    Kilimanjaro  ...              never pay     never pay          soft
# 59392          Mbeya  ...              never pay     never pay          soft
# 59393         Tabora  ...         pay per bucket    per bucket          soft
# 59394       Morogoro  ...            pay monthly       monthly          soft
# 59395    Kilimanjaro  ...         pay per bucket    per bucket          soft
# 59396         Iringa  ...           pay annually      annually          soft
# 59397          Mbeya  ...            pay monthly       monthly      fluoride
# 59398         Dodoma  ...              never pay     never pay          soft
# 59399       Morogoro  ...  pay when scheme fails    on failure         salty
#
#       quality_group      quantity                source           source_type  \
# 0              good        enough                spring                spring
# 1              good  insufficient  rainwater harvesting  rainwater harvesting
# 2              good        enough                   dam                   dam
# 3              good           dry           machine dbh              borehole
# 4              good      seasonal  rainwater harvesting  rainwater harvesting
# 5             salty        enough                 other                 other
# 6              good        enough           machine dbh              borehole
# 7             milky        enough          shallow well          shallow well
# 8             salty      seasonal           machine dbh              borehole
# 9              good        enough          shallow well          shallow well
# 10            salty        enough           machine dbh              borehole
# 11             good  insufficient          shallow well          shallow well
# 12             good        enough          shallow well          shallow well
# 13             good        enough                spring                spring
# 14             good        enough          shallow well          shallow well
# 15             good        enough           machine dbh              borehole
# 16             good           dry                 river            river/lake
# 17             good           dry                 river            river/lake
# 18            milky  insufficient                spring                spring
# 19             good        enough                spring                spring
# 20             good        enough                spring                spring
# 21          unknown       unknown          shallow well          shallow well
# 22             good        enough                 river            river/lake
# 23             good        enough                 river            river/lake
# 24             good        enough                spring                spring
# 25             good        enough                spring                spring
# 26             good        enough           machine dbh              borehole
# 27             good        enough          shallow well          shallow well
# 28             good  insufficient                spring                spring
# 29             good        enough                spring                spring
# ...             ...           ...                   ...                   ...
# 59370       unknown       unknown               unknown                 other
# 59371          good        enough          shallow well          shallow well
# 59372         salty  insufficient          shallow well          shallow well
# 59373          good        enough           machine dbh              borehole
# 59374          good        enough          shallow well          shallow well
# 59375          good        enough                 river            river/lake
# 59376       unknown           dry          shallow well          shallow well
# 59377          good  insufficient                   dam                   dam
# 59378          good        enough                spring                spring
# 59379          good        enough                spring                spring
# 59380          good           dry                spring                spring
# 59381          good  insufficient                spring                spring
# 59382          good        enough                spring                spring
# 59383          good        enough  rainwater harvesting  rainwater harvesting
# 59384          good  insufficient                spring                spring
# 59385         salty        enough           machine dbh              borehole
# 59386          good        enough           machine dbh              borehole
# 59387          good        enough           machine dbh              borehole
# 59388          good  insufficient                spring                spring
# 59389          good        enough           machine dbh              borehole
# 59390          good  insufficient           machine dbh              borehole
# 59391          good        enough                 river            river/lake
# 59392          good        enough                spring                spring
# 59393          good  insufficient                   dam                   dam
# 59394          good        enough           machine dbh              borehole
# 59395          good        enough                spring                spring
# 59396          good        enough                 river            river/lake
# 59397      fluoride        enough           machine dbh              borehole
# 59398          good  insufficient          shallow well          shallow well
# 59399         salty        enough          shallow well          shallow well
#
#       source_class              waterpoint_type  waterpoint_type_group
# 0      groundwater           communal standpipe     communal standpipe
# 1          surface           communal standpipe     communal standpipe
# 2          surface  communal standpipe multiple     communal standpipe
# 3      groundwater  communal standpipe multiple     communal standpipe
# 4          surface           communal standpipe     communal standpipe
# 5          unknown  communal standpipe multiple     communal standpipe
# 6      groundwater                    hand pump              hand pump
# 7      groundwater                    hand pump              hand pump
# 8      groundwater                    hand pump              hand pump
# 9      groundwater                    hand pump              hand pump
# 10     groundwater                        other                  other
# 11     groundwater                    hand pump              hand pump
# 12     groundwater                    hand pump              hand pump
# 13     groundwater           communal standpipe     communal standpipe
# 14     groundwater                    hand pump              hand pump
# 15     groundwater                    hand pump              hand pump
# 16         surface           communal standpipe     communal standpipe
# 17         surface           communal standpipe     communal standpipe
# 18     groundwater                        other                  other
# 19     groundwater           communal standpipe     communal standpipe
# 20     groundwater           communal standpipe     communal standpipe
# 21     groundwater                    hand pump              hand pump
# 22         surface           communal standpipe     communal standpipe
# 23         surface           communal standpipe     communal standpipe
# 24     groundwater              improved spring        improved spring
# 25     groundwater           communal standpipe     communal standpipe
# 26     groundwater                    hand pump              hand pump
# 27     groundwater                    hand pump              hand pump
# 28     groundwater           communal standpipe     communal standpipe
# 29     groundwater           communal standpipe     communal standpipe
# ...            ...                          ...                    ...
# 59370      unknown                        other                  other
# 59371  groundwater                    hand pump              hand pump
# 59372  groundwater                        other                  other
# 59373  groundwater                    hand pump              hand pump
# 59374  groundwater                    hand pump              hand pump
# 59375      surface           communal standpipe     communal standpipe
# 59376  groundwater                        other                  other
# 59377      surface  communal standpipe multiple     communal standpipe
# 59378  groundwater           communal standpipe     communal standpipe
# 59379  groundwater           communal standpipe     communal standpipe
# 59380  groundwater           communal standpipe     communal standpipe
# 59381  groundwater           communal standpipe     communal standpipe
# 59382  groundwater           communal standpipe     communal standpipe
# 59383      surface                    hand pump              hand pump
# 59384  groundwater           communal standpipe     communal standpipe
# 59385  groundwater                    hand pump              hand pump
# 59386  groundwater                    hand pump              hand pump
# 59387  groundwater           communal standpipe     communal standpipe
# 59388  groundwater              improved spring        improved spring
# 59389  groundwater                    hand pump              hand pump
# 59390  groundwater                    hand pump              hand pump
# 59391      surface           communal standpipe     communal standpipe
# 59392  groundwater           communal standpipe     communal standpipe
# 59393      surface                        other                  other
# 59394  groundwater           communal standpipe     communal standpipe
# 59395  groundwater           communal standpipe     communal standpipe
# 59396      surface           communal standpipe     communal standpipe
# 59397  groundwater                    hand pump              hand pump
# 59398  groundwater                    hand pump              hand pump
# 59399  groundwater                    hand pump              hand pump
#
# [59400 rows x 35 columns]

# %%
train_features['date_recorded'] = pd.to_datetime(train_features['date_recorded'], infer_datetime_format=True)

# %%
 # Extract components from date_recorded, then drop the original column
train_features['year_recorded'] = train_features['date_recorded'].dt.year
train_features['month_recorded'] = train_features['date_recorded'].dt.month
train_features['day_recorded'] = train_features['date_recorded'].dt.day
train_features = train_features.drop(columns='date_recorded')

# %%
# from pandas profiling we have 10 numerical and 26 categorical features. 2 boolean 

bool_features = ['public_meeting','permit']
categorical_features = train_features.select_dtypes(exclude=[np.number]).columns.to_list()
numerical_features = train_features.select_dtypes(include=[np.number]).columns.to_list()

# %%
len(numerical_features)
# Out:
# 13

# %%
#Remove boolean values from categorical_features
categorical_features = list(set(categorical_features) - set(bool_features))

# %%
# find if there are any NANs in categorical_features 
train_features[categorical_features].isnull().values.any()
# Out:
# True

# %%
len(categorical_features)
# Out:
# 27

# %%
#Since null values are only in categorical features, 
#I will find the top values in each and replace NANs with that value
def clean_data(lis):
    for element in lis:
        top = train_features[element].describe().to_list()[2]
        train_features[element]=train_features[element].fillna(top)

# %%
clean_data(categorical_features)
# No NaNs now
train_features[categorical_features].isnull().values.any()
# Out:
# False

# %%
#Split Training and Validation data

X_train = train_features
y_train = train_labels['status_group']

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=0.80, test_size=0.20,
    stratify=y_train, random_state=42)

X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((47520, 42), (11880, 42), (47520,), (11880,))

# %%
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())])
onehot_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(sparse=True, handle_unknown='ignore'))]) 
boolean_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent'))])
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numerical_features),
        ('boo', boolean_transformer, bool_features),
        ('one', onehot_transformer, categorical_features)])

# %%
dt = DecisionTreeClassifier(random_state=0)

# %%
classification = Pipeline(steps=[('preprocessor', preprocessor),
                      ('dt', DecisionTreeClassifier(max_depth=25))])

# %%
classification.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('preprocessor', ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#          transformer_weights=None,
#          transformers=[('num', Pipeline(memory=None,
#      steps=[('imputer', SimpleImputer(copy=True, fill_value=None, missing_values=nan, strategy='mean',
#        verbose...      min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'))])

# %%
print("Validation score: %.3f" % classification.score(X_val, y_val))
# Out:
# Validation score: 0.784

# %%
y_pred = classification.predict(test_features)
# Out:
# /Users/karthikmahendra/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
len(y_pred)
# Out:
# 14358

# %%
# Write submission csv file
submission = sample_submission.copy()
submission['status_group'] = y_pred
submission.to_csv('submission-03.csv', index=False)

# %%
rf = RandomForestClassifier(n_estimators=200)

# %%
classification = Pipeline(steps=[('preprocessor', preprocessor),
                      ('rf', RandomForestClassifier(max_depth=300,random_state=5))])

# %%
classification.fit(X_train, y_train)
# Out:
# /Users/karthikmahendra/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Pipeline(memory=None,
#      steps=[('preprocessor', ColumnTransformer(n_jobs=None, remainder='drop', sparse_threshold=0.3,
#          transformer_weights=None,
#          transformers=[('num', Pipeline(memory=None,
#      steps=[('imputer', SimpleImputer(copy=True, fill_value=None, missing_values=nan, strategy='mean',
#        verbose...imators=10, n_jobs=None,
#             oob_score=False, random_state=5, verbose=0, warm_start=False))])

# %%
print("Validation score: %.3f" % classification.score(X_val, y_val))
# Out:
# Validation score: 0.797

# %%
y_pred = classification.predict(test_features)
# Out:
# /Users/karthikmahendra/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1494: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
# Write submission csv file
submission = sample_submission.copy()
submission['status_group'] = y_pred
submission.to_csv('submission-05.csv', index=False)
